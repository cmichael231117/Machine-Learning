# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

file_data   = "mnist_test.csv"
handle_file = open(file_data, "r")
data        = handle_file.readlines()
handle_file.close()
handle_file = open(file_data, "r")
data2        = handle_file.readlines()
handle_file.close()

size_row    = 28    # height of the image
size_col    = 28    # width of the image

num_image   = len(data)
count       = 0     # count for the number of images

num_0 = 0
num_1 = 0
num_2 = 0
num_3 = 0
num_4 = 0
num_5 = 0
num_6 = 0
num_7 = 0
num_8 = 0
num_9 = 0

list_image  = np.empty((size_row * size_col, num_image), dtype=float)
list_label  = np.empty(num_image, dtype=int)

for line in data:

    line_data   = line.split(',')
    label       = line_data[0]
    im_vector   = np.asfarray(line_data[1:])

    list_label[count]       = label
    list_image[:, count]    = im_vector  
    
    if label == '0':
        num_0 += 1
    elif label == '1':
        num_1 += 1
    elif label == '2':
        num_2 += 1
    elif label == '3':
        num_3 += 1
    elif label == '4':
        num_4 += 1
    elif label == '5':
        num_5 += 1
    elif label == '6':
        num_6 += 1
    elif label == '7':
        num_7 += 1
    elif label == '8':
        num_8 += 1
    elif label == '9':
        num_9 += 1

    count += 1
    
f1 = plt.figure(1)

for i in range(100):
    label       = list_label[i]
    im_vector   = list_image[:, i]
    im_matrix   = im_vector.reshape((size_row, size_col))

    plt.subplot(10, 10, i+1)
    plt.title(label)
    plt.imshow(im_matrix, cmap='Greys', interpolation='None')

    frame   = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

plt.show()

# %%
list_image_0 = np.empty((size_row * size_col, num_0), dtype=float)
list_image_1 = np.empty((size_row * size_col, num_1), dtype=float)
list_image_2 = np.empty((size_row * size_col, num_2), dtype=float)
list_image_3 = np.empty((size_row * size_col, num_3), dtype=float)
list_image_4 = np.empty((size_row * size_col, num_4), dtype=float)
list_image_5 = np.empty((size_row * size_col, num_5), dtype=float)
list_image_6 = np.empty((size_row * size_col, num_6), dtype=float)
list_image_7 = np.empty((size_row * size_col, num_7), dtype=float)
list_image_8 = np.empty((size_row * size_col, num_8), dtype=float)
list_image_9 = np.empty((size_row * size_col, num_9), dtype=float)

count_0 = 0
count_1 = 0
count_2 = 0
count_3 = 0
count_4 = 0
count_5 = 0
count_6 = 0
count_7 = 0
count_8 = 0
count_9 = 0

for line in data:

    line_data   = line.split(',')
    label       = line_data[0]
    im_vector   = np.asfarray(line_data[1:])  
    
    if label == '0':
        list_image_0[:, count_0] = im_vector
        count_0 += 1
    elif label == '1':
        list_image_1[:, count_1] = im_vector
        count_1 += 1
    elif label == '2':
        list_image_2[:, count_2] = im_vector
        count_2 += 1
    elif label == '3':
        list_image_3[:, count_3] = im_vector
        count_3 += 1
    elif label == '4':
        list_image_4[:, count_4] = im_vector
        count_4 += 1
    elif label == '5':
        list_image_5[:, count_5] = im_vector
        count_5 += 1
    elif label == '6':
        list_image_6[:, count_6] = im_vector
        count_6 += 1
    elif label == '7':
        list_image_7[:, count_7] = im_vector
        count_7 += 1
    elif label == '8':
        list_image_8[:, count_8] = im_vector
        count_8 += 1
    elif label == '9':
        list_image_9[:, count_9] = im_vector
        count_9 += 1

# %%
for i in range(100):
    im_vector   = list_image_1[:, i]
    im_matrix   = im_vector.reshape((size_row, size_col))

    plt.subplot(10, 10, i+1)
    plt.imshow(im_matrix, cmap='Greys', interpolation='None')

    frame   = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)

plt.show()

# %%
sum_list_image_0 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_0):
    im_vector = list_image_0[:,i:i+1]
    sum_list_image_0 = sum_list_image_0 + im_vector
sum_list_image_0 = sum_list_image_0 / num_0
plt.imshow(sum_list_image_0.reshape((size_row, size_col)), cmap='Greys', interpolation='None')

# %%
sum_list_image_1 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_1):
    im_vector = list_image_1[:,i:i+1]
    sum_list_image_1 = sum_list_image_1 + im_vector
sum_list_image_1 = sum_list_image_1 / num_1

sum_list_image_2 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_2):
    im_vector = list_image_2[:,i:i+1]
    sum_list_image_2 = sum_list_image_2 + im_vector
sum_list_image_2 = sum_list_image_2 / num_2

sum_list_image_3 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_3):
    im_vector = list_image_3[:,i:i+1]
    sum_list_image_3 = sum_list_image_3 + im_vector
sum_list_image_3 = sum_list_image_3 / num_3

sum_list_image_4 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_4):
    im_vector = list_image_4[:,i:i+1]
    sum_list_image_4 = sum_list_image_4 + im_vector
sum_list_image_4 = sum_list_image_4 / num_4

sum_list_image_5 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_5):
    im_vector = list_image_5[:,i:i+1]
    sum_list_image_5 = sum_list_image_5 + im_vector
sum_list_image_5 = sum_list_image_5 / num_5

sum_list_image_6 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_6):
    im_vector = list_image_6[:,i:i+1]
    sum_list_image_6 = sum_list_image_6 + im_vector
sum_list_image_6 = sum_list_image_6 / num_6

sum_list_image_7 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_7):
    im_vector = list_image_7[:,i:i+1]
    sum_list_image_7 = sum_list_image_7 + im_vector
sum_list_image_7 = sum_list_image_7 / num_7

sum_list_image_8 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_8):
    im_vector = list_image_8[:,i:i+1]
    sum_list_image_8 = sum_list_image_8 + im_vector
sum_list_image_8 = sum_list_image_8 / num_8

sum_list_image_9 = np.zeros((size_row * size_col, 1), dtype=float)
for i in range(num_9):
    im_vector = list_image_9[:,i:i+1]
    sum_list_image_9 = sum_list_image_9 + im_vector
sum_list_image_9 = sum_list_image_9 / num_9

# %%
plt.subplot(2,5,1)
plt.imshow(sum_list_image_0.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,2)
plt.imshow(sum_list_image_1.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,3)
plt.imshow(sum_list_image_2.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,4)
plt.imshow(sum_list_image_3.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,5)
plt.imshow(sum_list_image_4.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,6)
plt.imshow(sum_list_image_5.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,7)
plt.imshow(sum_list_image_6.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,8)
plt.imshow(sum_list_image_7.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,9)
plt.imshow(sum_list_image_8.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)

plt.subplot(2,5,10)
plt.imshow(sum_list_image_9.reshape((size_row, size_col)), cmap='Greys', interpolation='None')
frame   = plt.gca()
frame.axes.get_xaxis().set_visible(False)
frame.axes.get_yaxis().set_visible(False)
